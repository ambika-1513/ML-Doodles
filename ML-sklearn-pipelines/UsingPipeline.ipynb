# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier

# %%
# missing_values -> one-hot_encoding -> scaling -> feature_selection ->model training ->predii

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns =['PassengerId' , 'Name', 'Ticket' , 'Cabin'], inplace =True)

# %%
# Step 1 -> train/test/split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['Survived']),
                                                 df['Survived'],
                                                 test_size=0.2,
                                                random_state=42)

# %%
X_train.head()
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 331       1    male  45.5      0      0  28.5000        S
# 733       2    male  23.0      0      0  13.0000        S
# 382       3    male  32.0      0      0   7.9250        S
# 704       3    male  26.0      1      0   7.8542        S
# 813       3  female   6.0      4      2  31.2750        S

# %%
y_train.head()
# Out:
# 331    0
# 733    0
# 382    0
# 704    0
# 813    0
# Name: Survived, dtype: int64

# %%
#missing values
trf1 = ColumnTransformer([
    ('impute_age' , SimpleImputer() ,[2]),
    ('impute_embarked', SimpleImputer(strategy = 'most_frequent'), [6])
                        ] , remainder = 'passthrough')

# %%
#onehotencoding
trf2 = ColumnTransformer([
    ('ohe_sex_embark' ,OneHotEncoder(sparse_output = False , handle_unknown = 'ignore') ,[1,6])], remainder ='passthrough')

# %%
#scaling
trf3 = ColumnTransformer([
            ('scaling' , MinMaxScaler() , slice(0,10))])

# %%
#Feature Selection
trf4 = SelectKBest(score_func = chi2 , k = 8)

# %%
#traininnnnn
trf5 = DecisionTreeClassifier()

# %%
#pipeline
pipe = Pipeline([
     ('trf1',trf1),
    ('trf2' , trf2),
    ('trf3' , trf3),
    ('trf4' , trf4),
    ('trf5', trf5)])

# %%
#alternae syntax of pipeline
pipe = make_pipeline(trf1,trf2,trf3,trf4,trf5)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute_age', SimpleImputer(),
#                                                   [2]),
#                                                  ('impute_embarked',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [6])])),
#                 ('columntransformer-2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe_sex_embark',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [1, 6])])),
#                 ('columntransformer-3',
# ...

# %%
pipe.named_steps
# Out:
# {'columntransformer-1': ColumnTransformer(remainder='passthrough',
#                    transformers=[('impute_age', SimpleImputer(), [2]),
#                                  ('impute_embarked',
#                                   SimpleImputer(strategy='most_frequent'),
#                                   [6])]),
#  'columntransformer-2': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ohe_sex_embark',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse_output=False),
#                                   [1, 6])]),
#  'columntransformer-3': ColumnTransformer(transformers=[('scaling', MinMaxScaler(),
#                                   slice(0, 10, None))]),
#  'selectkbest': SelectKBest(k=8, score_func=<function chi2 at 0x000002BF9956F7E0>),
#  'decisiontreeclassifier': DecisionTreeClassifier()}

# %%
pipe.named_steps['columntransformer-1'].transformers_[0][1].statistics_
# Out:
# array([29.49884615])

# %%
pipe.named_steps['columntransformer-3'].transformers_[0][1]
# Out:
# MinMaxScaler()

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6256983240223464

# %%
# cross validation using cross_val_score
from sklearn.model_selection import cross_val_score
cross_val_score(pipe, X_train, y_train, cv=5, scoring='accuracy').mean()
# Out:
# np.float64(0.6391214419383433)

# %%
# gridsearchcv
params = {
    'decisiontreeclassifier__max_depth':[1,2]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(pipe,params , cv=5, scoring='accuracy')
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer-1',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('impute_age',
#                                                                          SimpleImputer(),
#                                                                          [2]),
#                                                                         ('impute_embarked',
#                                                                          SimpleImputer(strategy='most_frequent'),
#                                                                          [6])])),
#                                        ('columntransformer-2',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe_sex_embark',
# ...

# %%
grid.best_score_
# Out:
# np.float64(0.6391214419383433)

# %%
grid.best_params_
# Out:
# {'decisiontreeclassifier__max_depth': 2}

# %%
# export 
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
